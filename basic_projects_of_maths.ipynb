# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth-aiml/python-projects/blob/main/basic_projects_of_maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lecture practice.
#type conversion
a = int("123") #always type a number string here.
b = 45 #int here
sum = "hello" + str(45)
print(type(a))
print(sum)
# Out:
# <class 'int'>
# hello45

# %% [markdown]
# # Compound Interest Calculator - FinCAT.inc
#
#
# p = float(input("Enter your principal (₹): "))
#
# t = float(input("Enter time in years: "))
#
# r = float(input("Enter rate of interest (%): "))
#
# a = p * (1 + r/100)**t
#
# ci = a - p
#
# print(f"\n--- FinCAT Results ---")
#
# print(f"Principal Amount:  ₹{p:,.2f}")
#
# print(f"Rate of Interest:  {r}%")
#
# print(f"Time Period:       {t} years")
#
# print(f"Final Amount:      ₹{round(a, 2):,.2f}")
#
# print(f"Compound Interest: ₹{round(ci, 2):,.2f}")

# %%
# Compound Interest Calculator - FinCAT.inc

p = float(input("Enter your principal (₹): "))

t = float(input("Enter time in years: "))

r = float(input("Enter rate of interest (%): "))

a = p * (1 + r/100)**t

ci = a - p

print(f"\n--- FinCAT Results ---")

print(f"Principal Amount:  ₹{p:,.2f}")

print(f"Rate of Interest:  {r}%")

print(f"Time Period:       {t} years")

print(f"Final Amount:      ₹{round(a, 2):,.2f}")

print(f"Compound Interest: ₹{round(ci, 2):,.2f}")
# Out:
# Enter your principal (₹): 2000
# Enter time in years: 2
# Enter rate of interest (%): 10
#
# --- FinCAT Results ---
# Principal Amount:  ₹2,000.00
# Rate of Interest:  10.0%
# Time Period:       2.0 years
# Final Amount:      ₹2,420.00
# Compound Interest: ₹420.00

# %%
#practice for python
#write a program to input two numbers and print their sum
a = float(input("Enter your number here:"))
b = float(input("Enter your second number here:"))
answer = a+b
print("your answer is:",answer)
# Out:
# Enter your number here:45
# Enter your second number here:45
# your answer is: 90.0

# %%
#square area calculator
side = float(input("Enter your number here:"))
answer = side*side
print("answer =",answer)
# Out:
# Enter your number here:45
# answer = 2025.0

# %%
#avg of numbers calculator
a = float(input('Enter your number here:'))
b = float(input('Enter your second number here:'))
answer = a + b/2
print("Answer =",answer)
# Out:
# Enter your number here:45
# Enter your second number here:45
# Answer = 67.5

# %%
#numbers comparer
a = float(input("enter your number here:"))
b = float(input("enter your second number here:"))
answer = a>=b
print("your answer is:",answer)
# Out:
# enter your number here:45
# enter your second number here:69
# your answer is: False

# %%
# compound interest finder
p = float(input("enter your principal here:")) # principal
t = float(input("enter yuor time in yrs here:")) # time in years
r = float(input("enter your rate of interest here:")) # rate of interest
a = p * (1 + r/100)**t # formula
ci = a - p #formula
print("here is your amount",a)
print("your ci is:",ci)
# Out:
# enter your principal here:100000
# enter yuor time in yrs here:10
# enter your rate of interest here:10
# here is your amount 259374.24601000024
# your ci is: 159374.24601000024

# %%
import pandas as pd

#expense tracker
print("------ExpenseTracker------")
print("Time to set up your budget and track expenses!")

# Function to get a valid float input with error handling and roasting
def get_float_input(prompt):
    while True:
        try:
            value = float(input(prompt))
            return value
        except ValueError:
            print("Seriously? That's not a number. Try again, this isn't rocket science.")

# Get Budget
budget = get_float_input("Enter your budget here: ")

expenses = {}
print("\nNow, let's add your expenses. Type 'done' when you're finished.")

while True:
    category_name = input("Enter an expense category (or 'done' to finish): ").strip()
    if category_name.lower() == 'done':
        break
    if not category_name: # Handle empty input for category name
        print("Please enter a category name or 'done'.")
        continue

    # Get amount for the current category
    amount_prompt = f"Enter the amount for '{category_name}': "
    expense_amount = get_float_input(amount_prompt)

    # Add to existing category or create a new one
    if category_name in expenses:
        expenses[category_name] += expense_amount
    else:
        expenses[category_name] = expense_amount

# Calculate total expenses
total = sum(expenses.values())

print("\n----Aapka total expense----")
for category, amount in expenses.items():
    print(f"{category} = {amount:,.2f}") # Formatted for better readability

print(f"Your total was : {total:,.2f}")

# Convert expenses to a DataFrame and save to CSV
if expenses:
    expenses_df = pd.DataFrame(list(expenses.items()), columns=['Category', 'Amount'])
    expenses_df.to_csv('expenses.csv', index=False)
    print("\nExpenses saved to expenses.csv")
else:
    print("\nNo expenses were entered, so no file was saved.")

if total > budget:
    print("Poor financial decisions! You've overspent your budget.")
elif total < budget:
    print("Warren Buffet IRL! You're under budget!")
else:
    print("Good thing Bro! You've hit your budget right on the mark.")
# Out:
# ------ExpenseTracker------
# Time to set up your budget and track expenses!
# Enter your budget here: tvgybi
# Seriously? That's not a number. Try again, this isn't rocket science.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2455/3536352696.py in <cell line: 0>()
#      15
#      16 # Get Budget
# ---> 17 budget = get_float_input("Enter your budget here: ")
#      18
#      19 expenses = {}
#
# /tmp/ipykernel_2455/3536352696.py in get_float_input(prompt)
#       9     while True:
#      10         try:
# ---> 11             value = float(input(prompt))
#      12             return value
#      13         except ValueError:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# ...

# %%
print("----calculator----")

def get_numeric_input(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("fuck you")

num1 = get_numeric_input("enter your first number here:")
num2 = get_numeric_input("enter your second number here:")

operations = input("choose operations here: +,-,/,*")
if operations == '+':
  print("Addition = ",num1 + num2)
elif operations == '-':
  print("Subtraction = ",num1 - num2)
elif operations == '*':
  print("Multiplication = ",num1 * num2)
elif operations == '/':
  if num2 != 0:
    print("Division = ",num1 / num2)
  else:
    print("fuck your mother")
else:
  print("fuck you")
# Out:
# ----calculator----
# enter your first number here:tfyv
# fuck you
# enter your first number here:5646841651
# enter your second number here:630
# choose operations here: +,-,/,*+
# Addition =  5646842281.0

# %%
#odd or even checker
def get_numeric_input(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("Fuck You")

num1 = get_numeric_input("Enter any number: ")
if(num1 % 2 == 0):
  print("it is an even number")
else:
  print("It is an odd number")
# Out:
# That's not a valid number. Please try again.
# That's not a valid number. Please try again.

# %%
#simple odd or even number checker
def get_numeric_input(prompt): #definition of get numeric input with prompt
  while True: #while true means condition is correct
    try: #trying to do error handling
      return float(input(prompt)) #returning float value
    except ValueError: #except float
      print("are you retarded") #print statement

num1 = get_numeric_input("enter a number: ") #get_numeric_input reused
if(num1 % 2 == 0): #if remainder is 0
  print("it is a even number") #print statement
else: #if not
  print("It is a odd number") #print statement
# Out:
# enter a number: 45
# It is a odd number
