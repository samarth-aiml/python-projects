# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth-aiml/python-projects/blob/main/basic_projects_of_maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lecture practice.
#type conversion
a = int("123") #always type a number string here.
b = 45 #int here
sum = "hello" + str(45)
print(type(a))
print(sum)
# Out:
# <class 'int'>
# hello45

# %%
#practice for python
#write a program to input two numbers and print their sum
a = float(input("Enter your number here:"))
b = float(input("Enter your second number here:"))
answer = a+b
print("your answer is:",answer)
# Out:
# Enter your number here:45
# Enter your second number here:45
# your answer is: 90.0

# %%
#square area calculator
side = float(input("Enter your number here:"))
answer = side*side
print("answer =",answer)
# Out:
# Enter your number here:45
# answer = 2025.0

# %%
#avg of numbers calculator
a = float(input('Enter your number here:'))
b = float(input('Enter your second number here:'))
answer = a + b/2
print("Answer =",answer)
# Out:
# Enter your number here:45
# Enter your second number here:45
# Answer = 67.5

# %%
#numbers comparer
a = float(input("enter your number here:"))
b = float(input("enter your second number here:"))
answer = a>=b
print("your answer is:",answer)
# Out:
# enter your number here:45
# enter your second number here:69
# your answer is: False

# %%
# compound interest finder
p = float(input("enter your principal here:"))
t = float(input("enter yuor time in yrs here:"))
r = float(input("enter your rate of interest here:"))
a = p * (1 + r/100)**t
ci = a - p
print("here is your amount",amount)
print("your ci is:",ci)
# Out:
# enter your principal here:544646
# enter yuor time in yrs here:526
# enter your rate of interest here:6
# here is your amount 2056.4874999999997
# your ci is: 1.1142931165122836e+19
